# %%
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt


def set_seed(seed_value=42):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.enabled = False

set_seed()

# %%
from pathlib import Path
import requests

peptide_url = 'http://bioinfo.dcc.ufmg.br/propedia/public/download/peptide.fasta'
receptor_url = 'http://bioinfo.dcc.ufmg.br/propedia/public/download/receptor.fasta'
peptide_data = requests.get(peptide_url).text
receptor_data = requests.get(receptor_url).text
with open('peptide.fasta', 'w') as f:
  f.write(peptide_data)
with open('receptor.fasta', 'w') as f:
  f.write(receptor_data)

peptides, receptors = [], []
with open('receptor.fasta', 'r') as f:
    for line in f.readlines():
        if not line.startswith('>'):
            receptors.append(line.replace('\n', ''))

with open('peptide.fasta', 'r') as f:
    for line in f.readlines():
        if not line.startswith('>'):
            peptides.append(line.replace('\n', ''))
assert len(peptides) == len(receptors)

# %%
# !wget https://mmseqs.com/latest/mmseqs-linux-avx2.tar.gz
# !tar xvzf mmseqs-linux-avx2.tar.gz
# !cp mmseqs/bin/mmseqs /usr/bin/
# !pip install biopython
# Out:
# --2023-10-27 05:39:06--  https://mmseqs.com/latest/mmseqs-linux-avx2.tar.gz
# Resolving mmseqs.com (mmseqs.com)... 147.46.145.74
# Connecting to mmseqs.com (mmseqs.com)|147.46.145.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45098845 (43M) [application/octet-stream]
# Saving to: ‘mmseqs-linux-avx2.tar.gz’
#
# mmseqs-linux-avx2.t 100%[===================>]  43.01M  12.1MB/s    in 3.8s
#
# 2023-10-27 05:39:10 (11.2 MB/s) - ‘mmseqs-linux-avx2.tar.gz’ saved [45098845/45098845]
#
# mmseqs/
# mmseqs/bin/
# mmseqs/bin/mmseqs
# mmseqs/matrices/
# mmseqs/matrices/blosum90.out
# mmseqs/matrices/blosum50.out
# mmseqs/matrices/blosum75.out
# mmseqs/matrices/PAM50.out
# mmseqs/matrices/blosum45.out
# mmseqs/matrices/VTML120.out
# mmseqs/matrices/blosum65.out
# mmseqs/matrices/PAM60.out
# mmseqs/matrices/VTML20.out
# mmseqs/matrices/PAM100.out
# mmseqs/matrices/PAM10.out
# mmseqs/matrices/PAM120.out
# mmseqs/matrices/PAM70.out
# mmseqs/matrices/PAM40.out
# mmseqs/matrices/nucleotide.out
# mmseqs/matrices/blosum85.out
# mmseqs/matrices/blosum95.out
# mmseqs/matrices/blosum100.out
# mmseqs/matrices/blosum40.out
# mmseqs/matrices/blosum60.out
# mmseqs/matrices/blosum30.out
# mmseqs/matrices/PAM140.out
# mmseqs/matrices/PAM170.out
# mmseqs/matrices/blosum62.out
# mmseqs/matrices/PAM20.out
# mmseqs/matrices/blosum80.out
# mmseqs/matrices/VTML160.out
# mmseqs/matrices/PAM110.out
# mmseqs/matrices/blosum35.out
# mmseqs/matrices/blosum70.out
# mmseqs/matrices/PAM30.out
# mmseqs/matrices/PAM160.out
# mmseqs/matrices/PAM190.out
# mmseqs/matrices/VTML10.out
# mmseqs/matrices/VTML80.out
# mmseqs/matrices/PAM90.out
# mmseqs/matrices/blosum55.out
# mmseqs/matrices/PAM150.out
# mmseqs/matrices/PAM80.out
# mmseqs/matrices/VTML40.out
# mmseqs/matrices/PAM180.out
# mmseqs/matrices/PAM130.out
# mmseqs/README.md
# mmseqs/util/
# mmseqs/util/bash-completion.sh
# mmseqs/examples/
# mmseqs/examples/DB.fasta
# mmseqs/examples/QUERY.fasta
# mmseqs/userguide.pdf
# mmseqs/LICENSE.md
# Collecting biopython
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.23.5)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %%
# !mmseqs createdb receptor.fasta receptorDB
# !mmseqs cluster receptorDB receptorDB_clu tmp --min-seq-id 0.5
# !mmseqs createtsv receptorDB receptorDB receptorDB_clu receptorDB_clu.tsv
# Out:
# createdb receptor.fasta receptorDB
#
# MMseqs Version:       	bb0a1b3569b9fe115f3bf63e5ba1da234748de23
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [19797] 0s 39ms
# Time for merging to receptorDB_h: 0h 0m 0s 5ms
# Time for merging to receptorDB: 0h 0m 0s 7ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 87ms
# Create directory tmp
# cluster receptorDB receptorDB_clu tmp --min-seq-id 0.5
#
# MMseqs Version:                     	bb0a1b3569b9fe115f3bf63e5ba1da234748de23
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# Target search mode                  	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.8
# Coverage mode                       	0
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	2
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.5
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Weight file name
# Cluster Weight threshold            	0.9
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 3.000000
# Set cluster mode SET COVER
# Set cluster iterations to 3
# linclust receptorDB tmp/7311599506489173896/clu_redundancy tmp/7311599506489173896/linclust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher receptorDB tmp/7311599506489173896/linclust/15316959514249181803/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 0 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# kmermatcher receptorDB tmp/7311599506489173896/linclust/15316959514249181803/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 0 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Database size: 19813 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 100.00% 19.81K 0s 150ms
# Sort kmer 0h 0m 0s 56ms
# Sort by rep. sequence 0h 0m 0s 41ms
# Time for fill: 0h 0m 0s 4ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 275ms
# rescorediagonal receptorDB receptorDB tmp/7311599506489173896/linclust/15316959514249181803/pref tmp/7311599506489173896/linclust/15316959514249181803/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.8 -a 0 --cov-mode 0 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 2 --compressed 0 -v 3
#
# [=================================================================] 100.00% 19.81K 0s 28ms
# Time for merging to pref_rescore1: 0h 0m 0s 5ms
# Time for processing: 0h 0m 0s 39ms
# clust receptorDB tmp/7311599506489173896/linclust/15316959514249181803/pref_rescore1 tmp/7311599506489173896/linclust/15316959514249181803/pre_clust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 19.81K 0s 73ms
# Sort entries
# Find missing connections
# Found 41028 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 19.81K 0s 105ms
# Add missing connections
# [=================================================================] 100.00% 19.81K 0s 86ms
#
# Time for read in: 0h 0m 0s 269ms
# Total time: 0h 0m 0s 275ms
#
# Size of the sequence database: 19813
# Size of the alignment database: 19813
# Number of clusters: 2528
#
# Writing results 0h 0m 0s 0ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 282ms
# createsubdb tmp/7311599506489173896/linclust/15316959514249181803/order_redundancy receptorDB tmp/7311599506489173896/linclust/15316959514249181803/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 2ms
# createsubdb tmp/7311599506489173896/linclust/15316959514249181803/order_redundancy tmp/7311599506489173896/linclust/15316959514249181803/pref tmp/7311599506489173896/linclust/15316959514249181803/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 3ms
# filterdb tmp/7311599506489173896/linclust/15316959514249181803/pref_filter1 tmp/7311599506489173896/linclust/15316959514249181803/pref_filter2 --filter-file tmp/7311599506489173896/linclust/15316959514249181803/order_redundancy --threads 2 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 100.00% 2.53K 0s 5ms
# Time for merging to pref_filter2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 8ms
# rescorediagonal tmp/7311599506489173896/linclust/15316959514249181803/input_step_redundancy tmp/7311599506489173896/linclust/15316959514249181803/input_step_redundancy tmp/7311599506489173896/linclust/15316959514249181803/pref_filter2 tmp/7311599506489173896/linclust/15316959514249181803/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.8 -a 0 --cov-mode 0 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 2 --compressed 0 -v 3
#
# [=================================================================] 100.00% 2.53K 0s 72ms
# Time for merging to pref_rescore2: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 85ms
# align tmp/7311599506489173896/linclust/15316959514249181803/input_step_redundancy tmp/7311599506489173896/linclust/15316959514249181803/input_step_redundancy tmp/7311599506489173896/linclust/15316959514249181803/pref_rescore2 tmp/7311599506489173896/linclust/15316959514249181803/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 2528 type: Aminoacid
# Target database size: 2528 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 2.53K 0s 404ms
# Time for merging to aln: 0h 0m 0s 1ms
# 3343 alignments calculated
# 3200 sequence pairs passed the thresholds (0.957224 of overall calculated)
# 1.265823 hits per query sequence
# Time for processing: 0h 0m 0s 407ms
# clust tmp/7311599506489173896/linclust/15316959514249181803/input_step_redundancy tmp/7311599506489173896/linclust/15316959514249181803/aln tmp/7311599506489173896/linclust/15316959514249181803/clust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 2.53K 0s 80ms
# Sort entries
# Find missing connections
# Found 672 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 2.53K 0s 1ms
# Add missing connections
# [=================================================================] 100.00% 2.53K 0s 98ms
#
# Time for read in: 0h 0m 0s 181ms
# Total time: 0h 0m 0s 183ms
#
# Size of the sequence database: 2528
# Size of the alignment database: 2528
# Number of clusters: 2097
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 185ms
# mergeclusters receptorDB tmp/7311599506489173896/clu_redundancy tmp/7311599506489173896/linclust/15316959514249181803/pre_clust tmp/7311599506489173896/linclust/15316959514249181803/clust --threads 2 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 2.53K 0s 3ms
# Clustering step 2
# [=================================================================] 100.00% 2.10K 0s 99ms
# Write merged clustering
# [=================================================================] 100.00% 19.81K 0s 108ms
# Time for merging to clu_redundancy: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 199ms
# createsubdb tmp/7311599506489173896/clu_redundancy receptorDB tmp/7311599506489173896/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 2ms
# prefilter tmp/7311599506489173896/input_step_redundancy tmp/7311599506489173896/input_step_redundancy tmp/7311599506489173896/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 0 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 2 --compressed 0 -v 3
#
# Query database size: 2097 type: Aminoacid
# Estimated memory consumption: 981M
# Target database size: 2097 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 2.10K 0s 158ms
# Index table: Masked residues: 7175
# Index table: fill
# [=================================================================] 100.00% 2.10K 0s 82ms
# Index statistics
# Entries:          229479
# DB size:          489 MB
# Avg k-mer size:   0.003586
# Top 10 k-mers
#     GVWVGA	14
#     GPLPHA	14
#     SDYVHA	14
#     DVPRGD	14
#     TRVKDF	14
#     TGDNEG	14
#     SPPSKG	14
#     PVRGRG	14
#     GGLCGH	14
#     YLTHVI	14
# Time for index table init: 0h 0m 1s 113ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 2097
# Target db start 1 to 2097
# [=================================================================] 100.00% 2.10K 0s 237ms
#
# 2.289449 k-mers per position
# 148 DB matches per sequence
# 0 overflows
# 2 sequences passed prefiltering per query sequence
# 1 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 1ms
# Time for processing: 0h 0m 3s 972ms
# align tmp/7311599506489173896/input_step_redundancy tmp/7311599506489173896/input_step_redundancy tmp/7311599506489173896/pref_step0 tmp/7311599506489173896/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 2097 type: Aminoacid
# Target database size: 2097 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 2.10K 0s 603ms
# Time for merging to aln_step0: 0h 0m 0s 1ms
# 4168 alignments calculated
# 3061 sequence pairs passed the thresholds (0.734405 of overall calculated)
# 1.459704 hits per query sequence
# Time for processing: 0h 0m 0s 628ms
# clust tmp/7311599506489173896/input_step_redundancy tmp/7311599506489173896/aln_step0 tmp/7311599506489173896/clu_step0 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 2.10K 0s 5ms
# Sort entries
# Find missing connections
# Found 0 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 2.10K 0s 27ms
# Add missing connections
# [=================================================================] 100.00% 2.10K 0s 1ms
#
# Time for read in: 0h 0m 0s 35ms
# Total time: 0h 0m 0s 38ms
#
# Size of the sequence database: 2097
# Size of the alignment database: 2097
# Number of clusters: 1849
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 120ms
# createsubdb tmp/7311599506489173896/clu_step0 tmp/7311599506489173896/input_step_redundancy tmp/7311599506489173896/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 1ms
# prefilter tmp/7311599506489173896/input_step1 tmp/7311599506489173896/input_step1 tmp/7311599506489173896/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 2 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 2 --compressed 0 -v 3
#
# Query database size: 1849 type: Aminoacid
# Estimated memory consumption: 980M
# Target database size: 1849 type: Aminoacid
# Index table k-mer threshold: 145 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 1.85K 0s 248ms
# Index table: Masked residues: 6309
# Index table: fill
# [=================================================================] 100.00% 1.85K 0s 97ms
# Index statistics
# Entries:          295038
# DB size:          489 MB
# Avg k-mer size:   0.004610
# Top 10 k-mers
#     GGDCDS	14
#     SCGSPL	11
#     KDCGGG	10
#     SGPRGS	7
#     CQDGLV	7
#     VHSGRT	6
#     YWQTTV	6
#     ACGSPL	5
#     GDGPCN	5
#     DAQDGP	5
# Time for index table init: 0h 0m 2s 165ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 145
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 1849
# Target db start 1 to 1849
# [=================================================================] 100.00% 1.85K 0s 681ms
#
# 9.363704 k-mers per position
# 171 DB matches per sequence
# 0 overflows
# 2 sequences passed prefiltering per query sequence
# 1 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 8s 426ms
# align tmp/7311599506489173896/input_step1 tmp/7311599506489173896/input_step1 tmp/7311599506489173896/pref_step1 tmp/7311599506489173896/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 1849 type: Aminoacid
# Target database size: 1849 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 1.85K 0s 559ms
# Time for merging to aln_step1: 0h 0m 0s 0ms
# 3143 alignments calculated
# 1871 sequence pairs passed the thresholds (0.595291 of overall calculated)
# 1.011898 hits per query sequence
# Time for processing: 0h 0m 0s 608ms
# clust tmp/7311599506489173896/input_step1 tmp/7311599506489173896/aln_step1 tmp/7311599506489173896/clu_step1 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 1.85K 0s 24ms
# Sort entries
# Find missing connections
# Found 2 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 1.85K 0s 1ms
# Add missing connections
# [=================================================================] 100.00% 1.85K 0s 82ms
#
# Time for read in: 0h 0m 0s 187ms
# Total time: 0h 0m 0s 215ms
#
# Size of the sequence database: 1849
# Size of the alignment database: 1849
# Number of clusters: 1837
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 217ms
# createsubdb tmp/7311599506489173896/clu_step1 tmp/7311599506489173896/input_step1 tmp/7311599506489173896/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 10ms
# prefilter tmp/7311599506489173896/input_step2 tmp/7311599506489173896/input_step2 tmp/7311599506489173896/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 2 --compressed 0 -v 3
#
# Query database size: 1837 type: Aminoacid
# Estimated memory consumption: 980M
# Target database size: 1837 type: Aminoacid
# Index table k-mer threshold: 136 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 1.84K 0s 177ms
# Index table: Masked residues: 6063
# Index table: fill
# [=================================================================] 100.00% 1.84K 0s 117ms
# Index statistics
# Entries:          380211
# DB size:          490 MB
# Avg k-mer size:   0.005941
# Top 10 k-mers
#     GGDCDS	14
#     SCGSPL	11
#     KDCGGG	10
#     SGPRGS	7
#     CQDGLV	7
#     VHSGRT	6
#     GKSQSG	5
#     ASPVVG	5
#     GDGPCK	5
#     DRILLK	5
# Time for index table init: 0h 0m 1s 450ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 136
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 1837
# Target db start 1 to 1837
# [=================================================================] 100.00% 1.84K 1s 150ms
#
# 27.227948 k-mers per position
# 243 DB matches per sequence
# 0 overflows
# 2 sequences passed prefiltering per query sequence
# 2 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 7s 5ms
# align tmp/7311599506489173896/input_step2 tmp/7311599506489173896/input_step2 tmp/7311599506489173896/pref_step2 tmp/7311599506489173896/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 1837 type: Aminoacid
# Target database size: 1837 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 1.84K 0s 789ms
# Time for merging to aln_step2: 0h 0m 0s 2ms
# 3642 alignments calculated
# 1843 sequence pairs passed the thresholds (0.506041 of overall calculated)
# 1.003266 hits per query sequence
# Time for processing: 0h 0m 0s 903ms
# clust tmp/7311599506489173896/input_step2 tmp/7311599506489173896/aln_step2 tmp/7311599506489173896/clu_step2 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 1.84K 0s 2ms
# Sort entries
# Find missing connections
# Found 0 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 1.84K 0s 65ms
# Add missing connections
# [=================================================================] 100.00% 1.84K 0s 8ms
#
# Time for read in: 0h 0m 0s 106ms
# Total time: 0h 0m 0s 136ms
#
# Size of the sequence database: 1837
# Size of the alignment database: 1837
# Number of clusters: 1834
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 138ms
# mergeclusters receptorDB receptorDB_clu tmp/7311599506489173896/clu_redundancy tmp/7311599506489173896/clu_step0 tmp/7311599506489173896/clu_step1 tmp/7311599506489173896/clu_step2 --threads 2 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 2.10K 0s 13ms
# Clustering step 2
# [=================================================================] 100.00% 1.85K 0s 51ms
# Clustering step 3
# [=================================================================] 100.00% 1.84K 0s 61ms
# Clustering step 4
# [=================================================================] 100.00% 1.83K 0s 79ms
# Write merged clustering
# [=================================================================] 100.00% 19.81K 0s 156ms
# Time for merging to receptorDB_clu: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 295ms
# createtsv receptorDB receptorDB receptorDB_clu receptorDB_clu.tsv
#
# MMseqs Version:                 	bb0a1b3569b9fe115f3bf63e5ba1da234748de23
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	2
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to receptorDB_clu.tsv: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 32ms

# %%
from Bio import SeqIO
id_to_seq = {}
receptors_parsed = list(SeqIO.parse('receptor.fasta', 'fasta'))
for receptor_parsed in receptors_parsed:
    id_to_seq[receptor_parsed.id] = str(receptor_parsed.seq)
receptor_to_peptide = dict(zip(receptors, peptides))

with open('receptorDB_clu.tsv', 'r') as f:
    clusters = {}
    for line in f:
        cluster_id, receptor_id = line.strip().split("\t")
        if cluster_id not in clusters:
            clusters[cluster_id] = []
        receptor_sequence = id_to_seq[receptor_id]
        peptide_sequence = receptor_to_peptide[receptor_sequence]
        clusters[cluster_id].append((peptide_sequence, receptor_sequence))

cluster_ids = list(clusters.keys())
random.shuffle(cluster_ids)
num_train = int(0.7 * len(cluster_ids))
num_val = int(0.15 * len(cluster_ids))
train_clusters = cluster_ids[:num_train]
val_clusters = cluster_ids[num_train:num_train+num_val]
test_clusters = cluster_ids[num_train+num_val:]

# %%
from torch.utils.data import Dataset, DataLoader

class PeptideReceptorDataset(Dataset):
    def __init__(self, clusters, cluster_ids):
        self.clusters = clusters
        self.cluster_ids = cluster_ids

    def __len__(self):
        return len(self.cluster_ids)

    def __getitem__(self, idx):
        curr_cluster = self.clusters[self.cluster_ids[idx]]
        curr_pair = random.choice(curr_cluster)
        peptide_sequence = curr_pair[0]
        receptor_sequence = curr_pair[1]
        return peptide_sequence, receptor_sequence

train_dataset = PeptideReceptorDataset(clusters, train_clusters)
val_dataset = PeptideReceptorDataset(clusters, val_clusters)
test_dataset = PeptideReceptorDataset(clusters, test_clusters)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 103.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
from transformers import EsmModel, EsmTokenizer
tokenizer = EsmTokenizer.from_pretrained("facebook/esm2_t6_8M_UR50D")
model = EsmModel.from_pretrained("facebook/esm2_t6_8M_UR50D")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/95.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/93.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/775 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/31.4M [00:00<?, ?B/s]
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['esm.pooler.dense.weight', 'esm.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def masked_mean(h, mask):
    masked_h = h * mask.unsqueeze(-1)
    sum_masked_h = masked_h.sum(dim=1)
    count_non_masked = mask.sum(dim=1, keepdim=True).clamp(min=1)
    mean_masked_h = sum_masked_h / count_non_masked
    return mean_masked_h

class ExtendedCLIP(nn.Module):
    def __init__(self, input_dim, h1, h2, esm_type='protein'):
        super(ExtendedCLIP, self).__init__()

        # esm
        self.encoder = EsmModel.from_pretrained("facebook/esm2_t6_8M_UR50D")

        # freeze all parameters
        for param in self.encoder.parameters():
            param.requires_grad = False

        # h1 feedforward layers
        self.pep_amino_acid_ffn = nn.ModuleList()
        for _ in range(h1):
            self.pep_amino_acid_ffn.append(nn.Linear(input_dim, input_dim))
        self.rec_amino_acid_ffn = nn.ModuleList()
        for _ in range(h1):
            self.rec_amino_acid_ffn.append(nn.Linear(input_dim, input_dim))

        # h2 feedforward layers
        self.pep_embedding_ffn = nn.ModuleList()
        for _ in range(h2):
            self.pep_embedding_ffn.append(nn.Linear(input_dim, input_dim))
        self.rec_embedding_ffn = nn.ModuleList()
        for _ in range(h2):
            self.rec_embedding_ffn.append(nn.Linear(input_dim, input_dim))

        # temp scaling
        self.t = nn.Parameter(torch.tensor(1.0))

    def forward(self, pep_seq, rec_seq):
        # esm
        pep_embedding = self.encoder(**pep_seq).last_hidden_state
        rec_embedding = self.encoder(**rec_seq).last_hidden_state

        # h1 layers on each amino acid
        for layer in self.pep_amino_acid_ffn:
            pep_embedding = torch.tanh(layer(pep_embedding))
        for layer in self.rec_amino_acid_ffn:
            rec_embedding = torch.tanh(layer(rec_embedding))

        # avg embeddings over sequence length
        pep_avg_embedding = masked_mean(pep_embedding, pep_seq['attention_mask'])
        rec_avg_embedding = masked_mean(rec_embedding, rec_seq['attention_mask'])

        # h2 layers on avg embeddings
        for layer in self.pep_embedding_ffn:
            pep_avg_embedding = torch.tanh(layer(pep_avg_embedding))
        for layer in self.rec_embedding_ffn:
            rec_avg_embedding = torch.tanh(layer(rec_avg_embedding))

        # normalize embeddings
        pep_norm_embedding = pep_avg_embedding / pep_avg_embedding.norm(dim=-1, keepdim=True).clamp(min=1e-9)
        rec_norm_embedding = rec_avg_embedding / rec_avg_embedding.norm(dim=-1, keepdim=True).clamp(min=1e-9)

        return pep_norm_embedding, rec_norm_embedding

def compute_similarity_matrix(model, peptides, receptors):
    pep_norm_embedding, rec_norm_embedding = model(peptides, receptors)
    similarity_matrix = torch.mm(pep_norm_embedding, rec_norm_embedding.t())
    return similarity_matrix

def compute_loss(similarity_matrix, temperature):
    logits = similarity_matrix / temperature
    n = logits.size(0)
    exp_logits = torch.exp(logits)
    L_r = -torch.mean(torch.log(torch.exp(torch.diag(logits)) / torch.sum(exp_logits, dim=1)))
    L_p = -torch.mean(torch.log(torch.exp(torch.diag(logits)) / torch.sum(exp_logits, dim=0)))
    return (L_r + L_p) * 0.5

from torch.cuda.amp import autocast, GradScaler
import gc

def train(model, data_loader, optimizer, device, grad_acc_steps=4):
    scaler = GradScaler()

    model.train()
    total_loss = 0
    optimizer.zero_grad()

    for batch_idx, (peptides, receptors) in enumerate(data_loader):
        with autocast():  # mixed precision context
            peptides = tokenizer(peptides, return_tensors='pt', padding=True).to(device)
            receptors = tokenizer(receptors, return_tensors='pt', padding=True).to(device)

            similarity_matrix = compute_similarity_matrix(model, peptides, receptors)
            loss = compute_loss(similarity_matrix, model.t)

            # mixed precision
            scaler.scale(loss).backward()

            # gradient accumulation
            # if (batch_idx + 1) % grad_acc_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

            total_loss += loss.item()

            del peptides
            del receptors
            del similarity_matrix
            del loss

    gc.collect()

    return total_loss / len(data_loader)

# def train(model, data_loader, optimizer, device):
#     model.train()
#     total_loss = 0
#     for batch_idx, (peptides, receptors) in enumerate(data_loader):
#         peptides = tokenizer(peptides, return_tensors='pt', padding=True).to(device)
#         receptors = tokenizer(receptors, return_tensors='pt', padding=True).to(device)
#         optimizer.zero_grad()
#         similarity_matrix = compute_similarity_matrix(model, peptides, receptors)
#         loss = compute_loss(similarity_matrix, model.t)
#         loss.backward()
#         optimizer.step()
#         total_loss += loss.item()
#     return total_loss / len(data_loader)

def evaluate(model, data_loader, device):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for batch_idx, (peptides, receptors) in enumerate(data_loader):
            peptides = tokenizer(peptides, return_tensors='pt', padding=True).to(device)
            receptors = tokenizer(receptors, return_tensors='pt', padding=True).to(device)

            similarity_matrix = compute_similarity_matrix(model, peptides, receptors)
            loss = compute_loss(similarity_matrix, model.t)

            total_loss += loss.item()

            del peptides
            del receptors
            del similarity_matrix
            del loss

    gc.collect()

    return total_loss / len(data_loader)

# %%
# cleaning gpu ram
torch.cuda.empty_cache()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
set_seed()
input_dim = 320
h1 = 2
h2 = 2
trained_model = ExtendedCLIP(input_dim, h1, h2).to(device)
optimizer = torch.optim.Adam(trained_model.parameters(), lr=1e-3)

num_epochs = 100
train_losses, val_losses = [], []
# Out:
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['esm.pooler.dense.weight', 'esm.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
curr_peptides, curr_receptors = next(iter(train_loader))
curr_peptides = tokenizer(curr_peptides, return_tensors='pt', padding=True).to(device)
curr_receptors = tokenizer(curr_receptors, return_tensors='pt', padding=True).to(device)

similarity_matrix = compute_similarity_matrix(trained_model, curr_peptides, curr_receptors)
similarity_matrix_np = similarity_matrix.cpu().detach().numpy()

plt.figure(figsize=(6, 4))
plt.imshow(similarity_matrix_np, cmap='viridis')
plt.colorbar()
plt.title("Raw Embedding Cosine Similarities")
plt.xlabel("Receptor Protein")
plt.ylabel("Peptide")
plt.show()

del curr_peptides
del curr_receptors
del similarity_matrix
del similarity_matrix_np
gc.collect()
# Out:
# 6192

# %%
for epoch in range(num_epochs):
    train_loss = train(trained_model, train_loader, optimizer, device)
    val_loss = evaluate(trained_model, val_loader, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    torch.cuda.empty_cache()  # Clearing GPU cache after each epoch

    print(f"Epoch {epoch + 1}/{num_epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1356 > 1024). Running this sequence through the model will result in indexing errors
# Epoch 1/100 - Train Loss: 3.3982, Val Loss: 3.3691
# Epoch 2/100 - Train Loss: 3.3391, Val Loss: 3.3481
# Epoch 3/100 - Train Loss: 3.3007, Val Loss: 3.3723
# Epoch 4/100 - Train Loss: 3.2648, Val Loss: 3.3054
# Epoch 5/100 - Train Loss: 3.2462, Val Loss: 3.3105
# Epoch 6/100 - Train Loss: 3.2069, Val Loss: 3.2905
# Epoch 7/100 - Train Loss: 3.1930, Val Loss: 3.3804
# Epoch 8/100 - Train Loss: 3.2034, Val Loss: 3.3050
# Epoch 9/100 - Train Loss: 3.1874, Val Loss: 3.3186
# Epoch 10/100 - Train Loss: 3.1877, Val Loss: 3.3195
# Epoch 11/100 - Train Loss: 3.1318, Val Loss: 3.3172
# Epoch 12/100 - Train Loss: 3.1347, Val Loss: 3.2847
# Epoch 13/100 - Train Loss: 3.1055, Val Loss: 3.3660
# Epoch 14/100 - Train Loss: 3.0969, Val Loss: 3.3503
# Epoch 15/100 - Train Loss: 3.0833, Val Loss: 3.3191
# Epoch 16/100 - Train Loss: 3.0520, Val Loss: 3.3210
# Epoch 17/100 - Train Loss: 3.0506, Val Loss: 3.3229
# Epoch 18/100 - Train Loss: 3.0509, Val Loss: 3.3362
# Epoch 19/100 - Train Loss: 3.0289, Val Loss: 3.3675
# Epoch 20/100 - Train Loss: 3.0159, Val Loss: 3.3251
# Epoch 21/100 - Train Loss: 2.9925, Val Loss: 3.3571
# Epoch 22/100 - Train Loss: 3.0341, Val Loss: 3.3827
# Epoch 23/100 - Train Loss: 2.9435, Val Loss: 3.3744
# Epoch 24/100 - Train Loss: 2.9270, Val Loss: 3.4014
# Epoch 25/100 - Train Loss: 2.9978, Val Loss: 3.4746
# Epoch 26/100 - Train Loss: 3.0002, Val Loss: 3.3113
# Epoch 27/100 - Train Loss: 2.9261, Val Loss: 3.4156
# Epoch 28/100 - Train Loss: 2.9365, Val Loss: 3.3650
# Epoch 29/100 - Train Loss: 2.9260, Val Loss: 3.4040
# Epoch 30/100 - Train Loss: 2.8998, Val Loss: 3.4370
# Epoch 31/100 - Train Loss: 2.8955, Val Loss: 3.4175
# Epoch 32/100 - Train Loss: 2.8799, Val Loss: 3.4528
# Epoch 33/100 - Train Loss: 2.8827, Val Loss: 3.4588
# Epoch 34/100 - Train Loss: 2.8500, Val Loss: 3.4172
# Epoch 35/100 - Train Loss: 2.8088, Val Loss: 3.4512
# Epoch 36/100 - Train Loss: 2.8204, Val Loss: 3.4146
# Epoch 37/100 - Train Loss: 2.8214, Val Loss: 3.3664
# Epoch 38/100 - Train Loss: 2.7832, Val Loss: 3.5618
# Epoch 39/100 - Train Loss: 2.7516, Val Loss: 3.5188
# Epoch 40/100 - Train Loss: 2.7357, Val Loss: 3.4640
# Epoch 41/100 - Train Loss: 2.6919, Val Loss: 3.4552
# Epoch 42/100 - Train Loss: 2.7238, Val Loss: 3.4066
# Epoch 43/100 - Train Loss: 2.6312, Val Loss: 3.5536
# Epoch 44/100 - Train Loss: 2.6825, Val Loss: 3.5101
# Epoch 45/100 - Train Loss: 2.6546, Val Loss: 3.4700
# Epoch 46/100 - Train Loss: 2.5676, Val Loss: 3.5127
# Epoch 47/100 - Train Loss: 2.5802, Val Loss: 3.6248
# Epoch 48/100 - Train Loss: 2.5642, Val Loss: 3.5969
# Epoch 49/100 - Train Loss: 2.5213, Val Loss: 3.5557
# Epoch 50/100 - Train Loss: 2.4650, Val Loss: 3.4468
# Epoch 51/100 - Train Loss: 2.4492, Val Loss: 3.5738
# Epoch 52/100 - Train Loss: 2.4379, Val Loss: 3.5477
# Epoch 53/100 - Train Loss: 2.4232, Val Loss: 3.6674
# Epoch 54/100 - Train Loss: 2.3814, Val Loss: 3.7084
# Epoch 55/100 - Train Loss: 2.4008, Val Loss: 3.5633
# Epoch 56/100 - Train Loss: 2.3892, Val Loss: 3.7564
# Epoch 57/100 - Train Loss: 2.2871, Val Loss: 3.7537
# Epoch 58/100 - Train Loss: 2.2605, Val Loss: 3.8086
# Epoch 59/100 - Train Loss: 2.2756, Val Loss: 3.6702
# Epoch 60/100 - Train Loss: 2.2438, Val Loss: 3.6631
# Epoch 61/100 - Train Loss: 2.2638, Val Loss: 3.9971
# Epoch 62/100 - Train Loss: 2.1685, Val Loss: 4.0311
# Epoch 63/100 - Train Loss: 2.1661, Val Loss: 3.7700
# Epoch 64/100 - Train Loss: 2.1410, Val Loss: 3.9004
# Epoch 65/100 - Train Loss: 2.0446, Val Loss: 4.0545
# Epoch 66/100 - Train Loss: 2.0831, Val Loss: 4.0579
# Epoch 67/100 - Train Loss: 2.0687, Val Loss: 3.9595
# Epoch 68/100 - Train Loss: 2.0102, Val Loss: 4.0699
# Epoch 69/100 - Train Loss: 1.9034, Val Loss: 4.2725
# Epoch 70/100 - Train Loss: 1.9698, Val Loss: 4.1832
# Epoch 71/100 - Train Loss: 1.9247, Val Loss: 4.0059
# Epoch 72/100 - Train Loss: 1.9456, Val Loss: 3.9949
# Epoch 73/100 - Train Loss: 1.8637, Val Loss: 4.1552
# Epoch 74/100 - Train Loss: 1.7642, Val Loss: 4.1088
# Epoch 75/100 - Train Loss: 1.7414, Val Loss: 4.0946
# Epoch 76/100 - Train Loss: 1.7231, Val Loss: 4.7430
# Epoch 77/100 - Train Loss: 1.7105, Val Loss: 4.3848
# Epoch 78/100 - Train Loss: 1.6477, Val Loss: 4.5099
# Epoch 79/100 - Train Loss: 1.5851, Val Loss: 5.4134
# Epoch 80/100 - Train Loss: 1.6710, Val Loss: 4.6878
# Epoch 81/100 - Train Loss: 1.5507, Val Loss: 4.6476
# Epoch 82/100 - Train Loss: 1.5274, Val Loss: 4.3226
# Epoch 83/100 - Train Loss: 1.4329, Val Loss: 4.7415
# Epoch 84/100 - Train Loss: 1.5009, Val Loss: 4.5986
# Epoch 85/100 - Train Loss: 1.5086, Val Loss: 4.4404
# Epoch 86/100 - Train Loss: 1.3708, Val Loss: 4.7261
# Epoch 87/100 - Train Loss: 1.3735, Val Loss: 4.9084
# Epoch 88/100 - Train Loss: 1.3559, Val Loss: 5.2560
# Epoch 89/100 - Train Loss: 1.3589, Val Loss: 4.9144
# Epoch 90/100 - Train Loss: 1.3204, Val Loss: 5.0378
# Epoch 91/100 - Train Loss: 1.3060, Val Loss: 5.5449
# Epoch 92/100 - Train Loss: 1.1767, Val Loss: 5.4334
# Epoch 93/100 - Train Loss: 1.2188, Val Loss: 5.1279
# Epoch 94/100 - Train Loss: 1.1770, Val Loss: 5.3606
# Epoch 95/100 - Train Loss: 1.1964, Val Loss: 5.6070
# Epoch 96/100 - Train Loss: 1.0911, Val Loss: 5.4069
# Epoch 97/100 - Train Loss: 1.0953, Val Loss: 6.5108
# Epoch 98/100 - Train Loss: 1.0632, Val Loss: 4.9606
# Epoch 99/100 - Train Loss: 1.0636, Val Loss: 5.3239
# Epoch 100/100 - Train Loss: 1.0424, Val Loss: 4.9353

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# eval on test set
test_loss = evaluate(trained_model, test_loader, device)
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 5.1756

# %%
curr_peptides, curr_receptors = next(iter(train_loader))
curr_peptides = tokenizer(curr_peptides, return_tensors='pt', padding=True).to(device)
curr_receptors = tokenizer(curr_receptors, return_tensors='pt', padding=True).to(device)

similarity_matrix = compute_similarity_matrix(trained_model, curr_peptides, curr_receptors)
similarity_matrix_np = similarity_matrix.cpu().detach().numpy()

plt.figure(figsize=(6, 4))
plt.imshow(similarity_matrix_np, cmap='viridis')
plt.colorbar()
plt.title("Trained Embedding Cosine Similarities")
plt.xlabel("Receptor Protein")
plt.ylabel("Peptide")
plt.show()

del curr_peptides
del curr_receptors
del similarity_matrix
del similarity_matrix_np
gc.collect()
# Out:
# 6577

# %%
torch.save(trained_model.state_dict(), 'temp.pth')

# %%
trained_model = ExtendedCLIP(320, 2, 2)
trained_model.load_state_dict(torch.load('temp.pth'))
trained_model.to(device)
# Out:
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['esm.pooler.dense.weight', 'esm.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ExtendedCLIP(
#   (encoder): EsmModel(
#     (embeddings): EsmEmbeddings(
#       (word_embeddings): Embedding(33, 320, padding_idx=1)
#       (dropout): Dropout(p=0.0, inplace=False)
#       (position_embeddings): Embedding(1026, 320, padding_idx=1)
#     )
#     (encoder): EsmEncoder(
#       (layer): ModuleList(
#         (0-5): 6 x EsmLayer(
#           (attention): EsmAttention(
#             (self): EsmSelfAttention(
#               (query): Linear(in_features=320, out_features=320, bias=True)
#               (key): Linear(in_features=320, out_features=320, bias=True)
#               (value): Linear(in_features=320, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (rotary_embeddings): RotaryEmbedding()
#             )
#             (output): EsmSelfOutput(
#               (dense): Linear(in_features=320, out_features=320, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (LayerNorm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#           )
#           (intermediate): EsmIntermediate(
#             (dense): Linear(in_features=320, out_features=1280, bias=True)
#           )
#           (output): EsmOutput(
#             (dense): Linear(in_features=1280, out_features=320, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (LayerNorm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (emb_layer_norm_after): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#     (pooler): EsmPooler(
#       (dense): Linear(in_features=320, out_features=320, bias=True)
#       (activation): Tanh()
#     )
#     (contact_head): EsmContactPredictionHead(
#       (regression): Linear(in_features=120, out_features=1, bias=True)
#       (activation): Sigmoid()
#     )
#   )
#   (pep_amino_acid_ffn): ModuleList(
#     (0-1): 2 x Linear(in_features=320, out_features=320, bias=True)
#   )
#   (rec_amino_acid_ffn): ModuleList(
#     (0-1): 2 x Linear(in_features=320, out_features=320, bias=True)
#   )
#   (pep_embedding_ffn): ModuleList(
#     (0-1): 2 x Linear(in_features=320, out_features=320, bias=True)
#   )
#   (rec_embedding_ffn): ModuleList(
#     (0-1): 2 x Linear(in_features=320, out_features=320, bias=True)
#   )
# )
